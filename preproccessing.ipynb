# %%
import PIL
print(PIL.__version__)
# Out:
# 8.0.1

# %%
from PIL import Image
from matplotlib import pyplot as plt

# %%
image1=Image.open(r"D:\Study\Project\dataset\Missing_hole\01_missing_hole_01.jpg")
print(image1.format)
print(image1.size)
print(image1.mode)
# Out:
# JPEG
# (3034, 1586)
# RGB

# %%
plt.imshow(image1)
plt.show()
